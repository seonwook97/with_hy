# %% [markdown]
# ## FinanceDataReader
# - FinanceDataReader를 통한 종목별 주가, 지표 데이터 수집
# - FinanceDataReader는 한국 주식 가격, 미국주식 가격, 지수, 환율, 암호화폐 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리

# %%
import FinanceDataReader as fdr
import seaborn as sns
import set_matplotlib_hangul
# Out:
# Hangul OK in your Windows !!!

# %%
df_krx = fdr.StockListing('KRX-MARCAP')
df_krx.head(20)
# Out:
#       Code      Name Market Dept   Close ChangeCode  Changes  ChagesRatio  \
# 1   005930      삼성전자  KOSPI        78300          2     -600        -0.76
# 2   000660    SK하이닉스  KOSPI       128000          2     -500        -0.39
# 3   005935     삼성전자우  KOSPI        72300          2     -100        -0.14
# 4   035420     NAVER  KOSPI       349000          1     3500         1.01
# 5   207940  삼성바이오로직스  KOSPI       858000          1     1000         0.12
# 6   051910      LG화학  KOSPI       745000          2   -28000        -3.62
# 7   006400     삼성SDI  KOSPI       664000          1     5000         0.76
# 8   005380       현대차  KOSPI       211000          2     -500        -0.24
# 9   035720       카카오  KOSPI        97200          3        0         0.00
# 10  000270        기아  KOSPI        84300          2     -800        -0.94
# 11  068270      셀트리온  KOSPI       196000          2    -1000        -0.51
# 12  005490     POSCO  KOSPI       308000          1     2500         0.82
# ...

# %% [markdown]
# ## 종목 선정
# - 프로젝트를 진행하기에 앞서 먼저 시가총액이 높은 순으로 기업을 정하기로 하였다.
# - 시가총액이 높은만큼 주식시장에서의 거래량도 많을 뿐더러, 관련 기사들도 많이 나올 것이라 판단하였다.
# - 다만, 카카오페이, 카카오뱅크, 카카오 같은 같은 회사의 계열사가 포함될 경우는 시총이 높은 순으로 채택하고 다른 기업을 선정하기로 하였다.
# - 보통 어떤 기업의 증권 관련 기사를 찾아볼 때 사람마다의 관심도에 따라 세부계열사를 검색하기도 하지만 보편적으로 회사의 메인 계열사 또는 회사명을 많이 찾는다는 특징을 참고하였다.

# %%
df_krx.set_index('Name', inplace=True)

# %%
df_krx.head()
# Out:
#             Code Market Dept   Close ChangeCode  Changes  ChagesRatio    Open  \
# Name
# 삼성전자      005930  KOSPI        78300          2     -600        -0.76   79300
# SK하이닉스    000660  KOSPI       128000          2     -500        -0.39  128500
# 삼성전자우     005935  KOSPI        72300          2     -100        -0.14   72600
# NAVER     035420  KOSPI       349000          1     3500         1.01  348000
# 삼성바이오로직스  207940  KOSPI       858000          1     1000         0.12  855000
#
#             High     Low   Volume        Amount           Marcap      Stocks  \
# Name
# 삼성전자       79300   78200  8752269  687866612850  467433973665000  5969782550
# SK하이닉스    130000  128000  3050538  393630755000   93184302720000   728002365
# 삼성전자우      72600   72200   719944   52102139500   59494708410000   822886700
# NAVER     352000  344000   470236  164258368000   57253130665000   164049085
# 삼성바이오로직스  861000  845000    39680   33846094000   56769570000000    66165000
#
#          MarketId
# ...

# %%
top10_list = df_krx.loc[top10comp, ['Market', 'Marcap', 'Stocks']]
top10_list
# Out:
#        Market           Marcap      Stocks
# Name
# 삼성전자    KOSPI  467433973665000  5969782550
# SK하이닉스  KOSPI   93184302720000   728002365
# NAVER   KOSPI   57253130665000   164049085
# LG화학    KOSPI   52591295535000    70592343
# 현대차     KOSPI   45083987457000   213668187
# 카카오     KOSPI   43342062228000   445905990
# 셀트리온    KOSPI   27037637088000   137947128
# POSCO   KOSPI   26853545180000    87186835
# KB금융    KOSPI   25780091040000   415807920
# 신한지주    KOSPI   20457342338400   516599554
